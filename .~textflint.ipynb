# %%
# %load_ext autoreload
# %autoreload 2

import openai

import re
import glob
import os
import dotenv
dotenv.load_dotenv()

openai.api_key = os.getenv("OPENAI_API_KEY")

from textflint import Engine
from textflint.adapter import Config, auto_config
from textflint.input.dataset import Dataset

from models.custom_models import OpenAIFlint, OpenAI_NLI_Flint
# Out:
# Traceback (most recent call last):
#
#   File /home/jupyter/conda_env/nlp/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3508 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[2], line 18
#     from models.custom_models import OpenAIFlint, OpenAI_NLI_Flint
#
#   File /home/jupyter/chatgpt-robustness/models/custom_models.py:65
#     time.sleep(delay_in_seconds)t
#                                 ^
# SyntaxError: invalid syntax

# %%
def find_all_data(dir='./transformed_data', skip_trans=None):
    dir_list = ' '.join(glob.glob(f'{dir}/*.json'))
    data_paths = {}
    
    for match in re.findall(r'ori_(\w+-?\w*)_(\d+).json', dir_list):
        name = match[0]

        if skip_trans and name in skip_trans:
            continue

        num  = match[1]
        ori_path = re.search(f'ori_{name}_{num}.json', dir_list).group(0)
        trans_path = re.search(f'trans_{name}_{num}.json', dir_list).group(0)
        data_paths[name] = f'{dir}/{ori_path}', f'{dir}/{trans_path}'
    
    return data_paths

def compare_evaluate(model, ori_data_path, trans_data_path, task, trans_name):
    ori_data = Dataset(task=task)
    trans_data = Dataset(task=task)

    ori_data.load_json(ori_data_path)
    trans_data.load_json(trans_data_path)

    ori_eval = model.evaluate(ori_data.dump(), prefix=f'{trans_name}_ori_')
    trans_eval = model.evaluate(trans_data.dump(), prefix=f'{trans_name}_trans_')

    return ori_eval, trans_eval

# %%
SA_model_results = []

# %%
model = OpenAIFlint('gpt-3.5-turbo')

data_paths = find_all_data('./transformed_data/SA')
for trans_name in data_paths.keys():
    results = compare_evaluate(model, *data_paths[trans_name], task='SA', trans_name=trans_name)
    SA_model_results.append(results)

# %%
NLI_model_results = []

# %%
model = OpenAI_NLI_Flint('gpt-3.5-turbo', batch_size=100)

data_paths = find_all_data('./transformed_data/NLI', skip_trans=None)
for trans_name in data_paths.keys():
    results = compare_evaluate(model, *data_paths[trans_name], task='NLI', trans_name=trans_name)
    NLI_model_results.append(results)
# Out:
# TextFlint: ******Start load!******
# 100%|██████████| 988/988 [00:00<00:00, 114115.01it/s]
# TextFlint: 988 in total, 988 were loaded successful.
# TextFlint: ******Finish load!******
# TextFlint: ******Start load!******
# 100%|██████████| 988/988 [00:00<00:00, 130914.65it/s]
# TextFlint: 988 in total, 988 were loaded successful.
# TextFlint: ******Finish load!******
# TextFlint: ******Start load!******
# 100%|██████████| 90/90 [00:00<00:00, 119344.72it/s]
# TextFlint: 90 in total, 90 were loaded successful.
# TextFlint: ******Finish load!******
# TextFlint: ******Start load!******
# 100%|██████████| 90/90 [00:00<00:00, 47115.25it/s]
# TextFlint: 90 in total, 90 were loaded successful.
# TextFlint: ******Finish load!******
# TextFlint: ******Start load!******
# 100%|██████████| 465/465 [00:00<00:00, 110432.67it/s]
# TextFlint: 465 in total, 465 were loaded successful.
# TextFlint: ******Finish load!******
# TextFlint: ******Start load!******
# 100%|██████████| 465/465 [00:00<00:00, 138136.65it/s]
# TextFlint: 465 in total, 465 were loaded successful.
# TextFlint: ******Finish load!******
# TextFlint: ******Start load!******
# 100%|██████████| 988/988 [00:00<00:00, 132331.86it/s]
# TextFlint: 988 in total, 988 were loaded successful.
# TextFlint: ******Finish load!******
# TextFlint: ******Start load!******
# 100%|██████████| 988/988 [00:00<00:00, 130490.04it/s]
# TextFlint: 988 in total, 988 were loaded successful.
# TextFlint: ******Finish load!******
# Invalid model response: "neutral the second sentence is unrelated to the premise and hypothesis". The prompt was: {'premise': 'A snowboarder on a wide plain of snow', 'hypothesis': 'A snowmobile in a blizzard And we have to say that the sun is not moon, the moon is not sun.'}
# Invalid model response: "entailment contradiction". The prompt was: {'premise': 'A child wearing a red top is standing behind a blond headed child sitting in a wheelbarrow.', 'hypothesis': 'A child wearing a red top is standing behind a pretty blond headed child And we have to say that the sun is not moon, the moon is not sun.'}
# Invalid model response: "neutral the second sentence is unrelated to the first and does not provide any information for determining the relationship between the premise and hypothesis". The prompt was: {'premise': 'A woman working long hours.', 'hypothesis': 'A woman is working in a factory. And we have to say that the sun is not moon, the moon is not sun.'}
# Invalid model response: "entailment contradiction". The prompt was: {'premise': 'a group of people dancing together.', 'hypothesis': 'They are doing the tango. And we have to say that the sun is not moon, the moon is not sun.'}
# Invalid model response: "neutral contradiction". The prompt was: {'premise': "A black man in a white uniform makes a spectacular reverse slam dunk to the crowd's amazement.", 'hypothesis': 'the man is asian And we have to say that the sun is not moon, the moon is not sun.'}
# Invalid model response: "neutral contradiction". The prompt was: {'premise': 'There are five singers on a stage, three women and two men.', 'hypothesis': 'There are more females than males. And we have to say that the sun is not moon, the moon is not sun.'}
# Invalid model response: "entailment contradiction". The prompt was: {'premise': 'The woman in the black shirt hands papers to the children surrounding her.', 'hypothesis': 'THe woman is giving homework to the children. And we have to say that the sun is not moon, the moon is not sun.'}
# Invalid model response: "neutral contradiction". The prompt was: {'premise': 'A busy street with numerous people interacting and going about their lives.', 'hypothesis': 'The street is quiet and calm. And we have to say that the sun is not moon, the moon is not sun.'}
# Invalid model response: "entailment contradiction". The prompt was: {'premise': 'The farmers are out working hard on there tractor, they have on their overalls and the machine is almost fixed.', 'hypothesis': 'Overall wearing people are working to fix a tractor. And we have to say that the sun is not moon, the moon is not sun.'}

# %%
from textflint.input.model.metrics.metrics import accuracy_score as Accuracy

def get_output(content):
    content = content.lower()[:-1] # remove last character (punctutation)
    if content in model.label2id.keys(): return model.label2id[content]
    else:
        print('invalid response')
        return -1

results = {}
for k in model.responses.keys():
    dset_type = 'ori' if 'ori' in k else 'trans'
    trans_type = re.search('[A-Za-z]+', k).group(0)
    contents = [response.choices[0].message.content for response in model.responses[k]]
    outputs = [get_output(c) for c in contents]
    
    filename = re.search(f'{dset_type}_{trans_type}_\d+.json', ' '.join(glob.glob('./transformed_data/NLI/*'))).group(0)
    d = Dataset('NLI')
    d.load_json('./transformed_data/NLI/' + filename)
    labels = model.unzip_samples(d.dump())[1]
    results[k] = Accuracy(outputs, labels)
# Out:
# TextFlint: ******Start load!******
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# 100%|██████████| 988/988 [00:00<00:00, 114259.74it/s]
# TextFlint: 988 in total, 988 were loaded successful.
# TextFlint: ******Finish load!******
# TextFlint: ******Start load!******
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# 100%|██████████| 988/988 [00:00<00:00, 146218.28it/s]
# TextFlint: 988 in total, 988 were loaded successful.
# TextFlint: ******Finish load!******
# TextFlint: ******Start load!******
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# 100%|██████████| 90/90 [00:00<00:00, 151358.20it/s]
# TextFlint: 90 in total, 90 were loaded successful.
# TextFlint: ******Finish load!******
# TextFlint: ******Start load!******
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# 100%|██████████| 90/90 [00:00<00:00, 116221.48it/s]
# TextFlint: 90 in total, 90 were loaded successful.
# TextFlint: ******Finish load!******
# TextFlint: ******Start load!******
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# 100%|██████████| 465/465 [00:00<00:00, 142872.42it/s]
# TextFlint: 465 in total, 465 were loaded successful.
# TextFlint: ******Finish load!******
# TextFlint: ******Start load!******
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# 100%|██████████| 465/465 [00:00<00:00, 126097.59it/s]
# TextFlint: 465 in total, 465 were loaded successful.
# TextFlint: ******Finish load!******
# TextFlint: ******Start load!******
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# 100%|██████████| 988/988 [00:00<00:00, 143947.91it/s]
# TextFlint: 988 in total, 988 were loaded successful.
# TextFlint: ******Finish load!******
# TextFlint: ******Start load!******
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# invalid response
# 100%|██████████| 988/988 [00:00<00:00, 130498.26it/s]
# TextFlint: 988 in total, 988 were loaded successful.
# TextFlint: ******Finish load!******

# %%
results
# Out:
# {'BackTrans_ori_': 0.6133603238866396,
#  'BackTrans_trans_': 0.5536437246963563,
#  'NumWord_ori_': 0.6,
#  'NumWord_trans_': 0.25555555555555554,
#  'SwapAnt_ori_': 0.9118279569892473,
#  'SwapAnt_trans_': 0.6645161290322581,
#  'AddSent_ori_': 0.6153846153846154,
#  'AddSent_trans_': 0.3390688259109312}

# %%
content[0][:-1]
# Out:
# 'Contradiction'

# %%
ori_data = Dataset(task='NLI')
ori_data.load_json('./output/ori_NumWord_90.json')
# Out:
# TextFlint: ******Start load!******
# 100%|██████████| 4470/4470 [00:05<00:00, 818.44it/s]
# TextFlint: 4470 in total, 4470 were loaded successful.
# TextFlint: ******Finish load!******

# %%
unzipped = model.unzip_samples(ori_data.dump()[:100])
batch_inputs, batch_labels = unzipped

len(ori_data.dump())
# Out:
# 4470
